# %%
import pandas as pd
Capitals = [
    {"city": "Montgomery", "state": "Alabama"},
    {"city": "Juneau", "state": "Alaska"},
    {"city": "Phoenix", "state": "Arizona"},
    {"city": "Little Rock", "state": "Arkansas"},
    {"city": "Sacramento", "state": "California"},
    {"city": "Denver", "state": "Colorado"},
    {"city": "Hartford", "state": "Connecticut"},  
    {"city": "Dover", "state": "Delaware"},
    {"city": "Tallahassee", "state": "Florida"},
    {"city": "Atlanta", "state": "Georgia"},
    {"city": "Honolulu", "state": "Hawaii"},
    {"city": "Boise", "state": "Idaho"},
    {"city": "Springfield", "state": "Illinois"},
    {"city": "Indianapolis", "state": "Indiana"},
    {"city": "Des Moines", "state": "Iowa"},
    {"city": "Topeka", "state": "Kansas"},
    {"city": "Frankfort", "state": "Kentucky"},
    {"city": "Baton Rouge", "state": "Louisiana"},
    {"city": "Augusta", "state": "Maine"},
    {"city": "Annapolis", "state": "Maryland"},
    {"city": "Boston", "state": "Massachusetts"},
    {"city": "Lansing", "state": "Michigan"},
    {"city": "Saint Paul", "state": "Minnesota"},
    {"city": "Jackson", "state": "Mississippi"},
    {"city": "Jefferson City", "state": "Missouri"},
    {"city": "Helena", "state": "Montana"},
    {"city": "Lincoln", "state": "Nebraska"},
    {"city": "Carson City", "state": "Nevada"},
    {"city": "Concord", "state": "New Hampshire"},
    {"city": "Trenton", "state": "New Jersey"},
    {"city": "Santa Fe", "state": "New Mexico"},
    {"city": "Albany", "state": "New York"},
    {"city": "Raleigh", "state": "North Carolina"},
    {"city": "Bismarck", "state": "North Dakota"},
    {"city": "Columbus", "state": "Ohio"},
    {"city": "Oklahoma City", "state": "Oklahoma"},
    {"city": "Salem", "state": "Oregon"},
    {"city": "Harrisburg", "state": "Pennsylvania"},
    {"city": "Providence", "state": "Rhode Island"},
    {"city": "Columbia", "state": "South Carolina"},
    {"city": "Pierre", "state": "South Dakota"},
    {"city": "Nashville", 	"state":"Tennessee"},
    {"city":"Austin","state":"Texas"},
    {"city":"Salt Lake City","state":"Utah"},
    {"city":"Montpelier","state":"Vermont"},
    {"city":"Richmond","state":"Virginia"},
    {"city":"Olympia","state":"Washington"},
    {"city":"Charleston","state":"West Virginia"},
    {"city":"Madison","state":"Wisconsin"},
    {"city":"Cheyenne","state":"Wyoming"}
    
]

dataframe = pd.read_csv("uscities.csv")

dataframe = dataframe[dataframe['city'].isin([capital['city'] for capital in Capitals])]

dataframe = dataframe[['city', 'state_id', 'density']]
print(dataframe.head())
# Out:
#           city state_id  density
# 7      Atlanta       GA   1424.8
# 9       Boston       MA   5303.2
# 10     Phoenix       AZ   1210.3
# 18      Denver       CO   1800.3
# 26  Sacramento       CA   2054.1

# %%
dataframe.sort_values(by='density', ascending=False, inplace=True)
print(dataframe)
# Out:
#                  city state_id  density
# 9              Boston       MA   5303.2
# 114           Trenton       NJ   4566.7
# 2342           Albany       CA   4264.0
# 42         Providence       RI   3990.1
# 50           Hartford       CT   2665.3
# ...               ...      ...      ...
# 19356  Jefferson City       MT      7.4
# 27684      Harrisburg       NE      4.7
# 1473           Juneau       AK      4.6
# 30829          Albany       WY      4.4
# 23965      Sacramento       NM      2.2
#
# [364 rows x 3 columns]

# %%
#US coordinates range Latitude: 24.396308 to 49.384358, Longitude: -124.848974 to -66.885444
#query1 = 24,-124
#query2 = 24,-66
#query3 = 49,-124
#query4 = 49,-66
#query5 = 36,-95
#rank_fun = 121,122,123,124

query1_1 = [('Olympia', 772641), ('Boise', 679000), ('Denver', 462941), ('Santa Fe', 426444), ('Sacramento', 418356), ('Salem', 388148), ('Cheyenne', 332215), ('Salt LakeCity', 310492), ('Phoenix', 266186), ('Carson City', 140829)]
query1_2 = [('Denver', 1816848), ('Boise', 1049748), ('Olympia', 959153), ('Phoenix', 953475), ('Salt Lake City', 849712), ('Sacramento', 804125), ('Salem', 772437), ('Cheyenne', 393387), ('Santa Fe', 307837), ('Carson City', 275166)]
query1_3 = [('Phoenix', 1883798), ('Denver', 1614267), ('Sacramento', 1556952), ('Salt Lake City', 1188795), ('Salem', 873927), ('Olympia', 674326), ('Boise', 632633), ('Cheyenne', 403540), ('Carson City', 288370), ('Santa Fe', 194936)]
query1_4 = [('Phoenix', 1107866), ('Denver', 1036801), ('Salt Lake City', 974857), ('Sacramento', 792886), ('Salem', 335407), ('Olympia', 235303), ('Boise', 195643), ('Cheyenne', 167014), ('Carson City', 133114), ('Santa Fe', 48150)]
query2_1 = [('Raleigh', 1301610), ('Trenton', 945206), ('Tallahassee', 937060), ('Richmond', 926139), ('Hartford', 896578), ('Harrisburg', 722524), ('Columbia', 706275), ('Annapolis', 546459), ('Dover', 538233), ('Providence', 391095)]
query2_2 = [('Richmond', 1311054), ('Trenton', 1204712), ('Harrisburg', 1162532), ('Columbia', 1114801), ('Hartford', 1004164), ('Raleigh', 951306), ('Providence', 626740), ('Tallahassee', 535752), ('Annapolis', 498082), ('Dover', 416093)]
query2_3 = [('Providence', 1404475), ('Hartford', 1202704), ('Columbia', 876417), ('Richmond', 824259), ('Harrisburg', 811378), ('Raleigh', 801448), ('Trenton', 797441), ('Tallahassee', 403805), ('Dover', 287875), ('Annapolis', 237084)]
query2_4 = [('Providence', 1163424), ('Richmond', 460921), ('Harrisburg', 435064), ('Columbia', 432515), ('Hartford', 390513), ('Trenton', 374994), ('Raleigh', 266391), ('Tallahassee', 147603), ('Dover', 125597), ('Annapolis', 79881)]
query3_1 = [('Olympia', 772641), ('Boise', 679000), ('Bismarck', 605542), ('Denver', 462941), ('Sacramento', 418356), ('Salem', 388148), ('Cheyenne', 332215), ('Salt LakeCity', 310492), ('Helena', 228397), ('Carson City', 140829)]
query3_2 = [('Denver', 1816848), ('Boise', 1049748), ('Olympia', 959153), ('Salt Lake City', 849712), ('Sacramento', 804125), ('Salem', 772437), ('Bismarck', 544707), ('Helena', 397145), ('Cheyenne', 393387), ('Carson City', 275166)]
query3_3 = [('Denver', 1614267), ('Sacramento', 1556952), ('Salt Lake City', 1188795), ('Salem', 873927), ('Olympia', 674326), ('Boise', 632633), ('Bismarck', 526797), ('Cheyenne', 403540), ('Helena', 344458), ('Carson City', 288370)]
query3_4 = [('Denver', 1036801), ('Salt Lake City', 974857), ('Sacramento', 792886), ('Salem', 335407), ('Olympia', 235303), ('Boise', 195643), ('Bismarck', 175693), ('Cheyenne', 167014), ('Carson City', 133114), ('Helena', 81190)]
query4_1 = [('Trenton', 945206), ('Hartford', 896578), ('Albany', 724629), ('Harrisburg', 722524), ('Dover', 538233), ('Providence', 391095), ('Augusta', 308796), ('Concord', 289453), ('Montpelier', 264503), ('Boston', 156971)]
query4_2 = [('Trenton', 1204712), ('Harrisburg', 1162532), ('Hartford', 1004164), ('Albany', 824089), ('Providence', 626740), ('Dover', 416093), ('Concord', 372622), ('Boston', 353395), ('Augusta', 310263), ('Montpelier', 194039)]
query4_3 = [('Providence', 1404475), ('Hartford', 1202704), ('Boston', 1133356), ('Albany', 859811), ('Harrisburg', 811378), ('Trenton', 797441), ('Concord', 301842), ('Dover', 287875), ('Augusta', 207378), ('Montpelier', 149048)]
query4_4 = [('Boston', 1731479), ('Providence', 1163424), ('Albany', 457878), ('Harrisburg', 435064), ('Hartford', 390513), ('Trenton', 374994), ('Dover', 125597), ('Concord', 118052), ('Augusta', 79156), ('Montpelier', 56414)]
query5_1 = [('Jackson', 846457), ('Des Moines', 739573), ('Austin', 705428), ('Topeka', 601105), ('Baton Rouge', 595120), ('Little Rock', 527456), ('Oklahoma City', 464727), ('Lincoln', 416240), ('Springfield', 378482), ('Jefferson City', 302501)]
query5_1 = [('Des Moines', 1341928), ('Little Rock', 1047726), ('Lincoln', 1013969), ('Oklahoma City', 948435), ('Topeka', 945405), ('Austin', 915567), ('Jackson', 883276), ('Baton Rouge', 836998), ('Springfield', 825634), ('Jefferson City', 377612)]
query5_1 = [('Oklahoma City', 1591035), ('Lincoln', 971919), ('Austin', 950835), ('Des Moines', 858142), ('Springfield', 815346), ('Little Rock', 790449), ('Baton Rouge',739464), ('Jackson', 632413), ('Topeka', 473487), ('Jefferson City', 290478)]
query5_1 = [('Oklahoma City', 965739), ('Austin', 696271), ('Little Rock', 507358), ('Lincoln', 447193), ('Des Moines', 410263), ('Baton Rouge', 374354), ('Jackson', 304335), ('Springfield', 259228), ('Topeka', 235826), ('Jefferson City', 96003)]
